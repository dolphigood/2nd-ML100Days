# %% [markdown]
# # 作業1
# ## S&P 500 stock data
# https://www.kaggle.com/camnugent/sandp500
# 1. 你選的這組資料為何重要
#     - 藉由S&P 500個股股價的歷史資料，尋找可能的規則，經五年時間資料的計算，尋找可能大於50%的勝率或長期期望值大於0的交易模式。
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#     - Cam Nugent藉由The Investor's Exchange api取得資料。
# 3. 蒐集而來的資料型態為何
#     - Date日期 - string
#     - Open開盤價 - float
#     - High最高價 - float
#     - Low最低價 - float
#     - Close收盤價 - float
#     - 成交量 - float
#     - 股名 - string
# 4. 這組資料想解決的問題如何評估
#     - 以過往的數據經學習後，使用後來的日期來判斷學習後的結果，只交易1單位的期望值是否可以大於0。

# %% [markdown]
# # 作業2
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#     - 提升總收入: 增加每車趟的里程數
#     - 提升每單位時間的收入: 降低空車率
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#     - 提升總收入
#         - (1) 不同區域不同時間叫車的客人搭乘里程數
#     - 提升每單位時間的收入
#         - (2) 不同區域不同時間出現叫車的頻率
# 3. 蒐集而來的資料型態為何
#     - (1) 區域, 時間, 乘車距離
#     - (2) 區域, 時間, 頻率
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#     - 如果假設正確，總收入需要增加，每單位時間的收入也需要增加。

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
def mean_squared_error(y,yp):
    import math
    total_rst = 0
    
    for rst in (y-yp):
        total_rst +=  math.pow(rst,2)
    
    mse = total_rst / len(y)
    
    return mse

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 258.510
# The Mean absolute error is 12.751
